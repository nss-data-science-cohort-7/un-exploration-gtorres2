# %% [markdown]
# #### Download data set. Create Jupyter Notebook, name it "UN_Data_Exploration". Import Pandas libraries.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %% [markdown]
# #### Read the GDP dataset into your notebook as a DataFrame called `gdp_df'.

# %%
gdp_df = pd.read_csv('gdp_per_capita.csv')
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %% [markdown]
# #### After reading it in, inspect the first 10 rows and then inspect the last 10 rows.

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2020  1970.560169              NaN
# 1     Afghanistan  2019  2065.036235              NaN
# 2     Afghanistan  2018  2033.804389              NaN
# 3     Afghanistan  2017  2058.400221              NaN
# 4     Afghanistan  2016  2057.067978              NaN
# 5     Afghanistan  2015  2068.265904              NaN
# 6     Afghanistan  2014  2102.384604              NaN
# 7     Afghanistan  2013  2116.465258              NaN
# 8     Afghanistan  2012  2075.491614              NaN
# 9     Afghanistan  2011  1904.559926              NaN

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7166        Zimbabwe  1999  2872.714795              NaN
# 7167        Zimbabwe  1998  2915.052992              NaN
# 7168        Zimbabwe  1997  2856.118188              NaN
# 7169        Zimbabwe  1996  2808.558556              NaN
# 7170        Zimbabwe  1995  2573.993785              NaN
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7176 entries, 0 to 7175
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7176 non-null   object
#  1   Year             7176 non-null   int64
#  2   Value            7176 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 224.4+ KB

# %% [markdown]
# #### Drop the 'Value Footnotes' column.

# %%
gdp_df = gdp_df.drop(columns=['Value Footnotes'])
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# #### Rename columns to 'Country', 'Year', and 'GDP_Per_Capita'

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# #### How many rows and columns does gdp_df have?
# 7,176 rows & 3 columns.
# #### What are the data types of its columns?
# Country = object, Year = interger, GDP = float
# #### If any of the columns are not the expected types, figure out why and fix it.

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7176 entries, 0 to 7175
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7176 non-null   object
#  1   Year            7176 non-null   int64
#  2   GDP_Per_Capita  7176 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 168.3+ KB

# %% [markdown]
# #### Which years are represented in this dataset?
#    From 1990-2018 (28 yrs)
# #### Take a look at the number of observations per year. What do you notice?
#    Growth every year, with steady growth from 2013-2018.

# %%
gdp_df['Year'].value_counts()
# Out:
# 2018    242
# 2017    242
# 2016    242
# 2015    242
# 2014    242
# 2013    242
# 2019    241
# 2020    240
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 1999    227
# 1998    226
# 1997    226
# 1996    222
# 1995    222
# 1994    211
# 1993    209
# 1992    208
# 1991    207
# 1990    206
# Name: Year, dtype: int64

# %% [markdown]
# #### How many countries are represented in this dataset?
#    242 countries
# #### Which countries are least represented in the dataset?
#    Somalia and Djibouti
# #### Why do you think these countries have so few observations?
#    Size

# %%
gdp_df['Country'].value_counts()
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: Country, Length: 242, dtype: int64

# %% [markdown]
# #### Create a new dataframe by subsetting `gdp_df` to just the year 2014. Call this new dataframe `gdp_2014`.

# %%
gdp_2014 = gdp_df[gdp_df['Year'] == 2014] 
gdp_2014
# Out:
#                           Country  Year  GDP_Per_Capita
# 6                     Afghanistan  2014     2102.384604
# 25    Africa Eastern and Southern  2014     3677.319414
# 56     Africa Western and Central  2014     4215.646000
# 87                        Albania  2014    11586.833878
# 118                       Algeria  2014    11512.690472
# ...                           ...   ...             ...
# 7031                      Vietnam  2014     7601.858491
# 7062           West Bank and Gaza  2014     5967.073437
# 7089                        World  2014    15224.439424
# 7120                       Zambia  2014     3450.037600
# 7151                     Zimbabwe  2014     2357.651166
#
# [242 rows x 3 columns]

# %% [markdown]
# #### Use `.describe()` to find the summary statistics for GDP per capita in 2014.

# %%
gdp_2014.describe()
# Out:
#          Year  GDP_Per_Capita
# count   242.0      242.000000
# mean   2014.0    19612.875611
# std       0.0    20961.714572
# min    2014.0      822.611195
# 25%    2014.0     4702.212961
# 50%    2014.0    12178.874687
# 75%    2014.0    26461.384188
# max    2014.0   155201.740571

# %% [markdown]
# #### Create a histogram of GDP Per Capita numbers for 2014 (you may wish to adjust the number of bins for your histogram). How would you describe the shape of the distribution?
#  Left skewed.

# %%
gdp_2014.plot.hist()
gdp_2014
# Out:
#                           Country  Year  GDP_Per_Capita
# 6                     Afghanistan  2014     2102.384604
# 25    Africa Eastern and Southern  2014     3677.319414
# 56     Africa Western and Central  2014     4215.646000
# 87                        Albania  2014    11586.833878
# 118                       Algeria  2014    11512.690472
# ...                           ...   ...             ...
# 7031                      Vietnam  2014     7601.858491
# 7062           West Bank and Gaza  2014     5967.073437
# 7089                        World  2014    15224.439424
# 7120                       Zambia  2014     3450.037600
# 7151                     Zimbabwe  2014     2357.651166
#
# [242 rows x 3 columns]

# %%
gdp_2014.hist(column = 'GDP_Per_Capita', figsize = [12,8], bins=15)
plt.show()

# %%
gdp_2014.hist(column = 'GDP_Per_Capita', by = 'Year', figsize = [12,8], bins=15)

plt.title('Histogram of GDP_Per_Capita')
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.show()

# %%
gdp_2014.hist(column='GDP_Per_Capita', bins=25, grid=False, figsize=(12,8), color = '#86bf91', zorder=2, rwidth=0.9)
# Out:
# array([[<AxesSubplot:title={'center':'GDP_Per_Capita'}>]], dtype=object)

# %% [markdown]
# Find the top 5 counties and bottom 5 countries by GDP per capita in 2018.

# %%
gdp_2018 = gdp_df[gdp_df['Year'] == 2018] 
gdp_2018
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 52     Africa Western and Central  2018     4132.592996
# 83                        Albania  2018    13317.092313
# 114                       Algeria  2018    11630.679409
# ...                           ...   ...             ...
# 7027                      Vietnam  2018     9548.700016
# 7058           West Bank and Gaza  2018     6318.210068
# 7085                        World  2018    16679.316815
# 7116                       Zambia  2018     3521.545978
# 7147                     Zimbabwe  2018     2497.136618
#
# [242 rows x 3 columns]

# %%
gdp_2018.head(10)
# Out:
#                          Country  Year  GDP_Per_Capita
# 2                    Afghanistan  2018     2033.804389
# 21   Africa Eastern and Southern  2018     3697.317275
# 52    Africa Western and Central  2018     4132.592996
# 83                       Albania  2018    13317.092313
# 114                      Algeria  2018    11630.679409
# 145                       Angola  2018     6982.129420
# 176          Antigua and Barbuda  2018    21017.264500
# 207                   Arab World  2018    14475.801957
# 238                    Argentina  2018    22747.241658
# 269                      Armenia  2018    12715.108954

# %%
gdp_2018.tail(10)
# Out:
#                   Country  Year  GDP_Per_Capita
# 6872        United States  2018    61339.838338
# 6903  Upper middle income  2018    16759.789169
# 6934              Uruguay  2018    23035.083388
# 6965           Uzbekistan  2018     7082.925493
# 6996              Vanuatu  2018     3093.086718
# 7027              Vietnam  2018     9548.700016
# 7058   West Bank and Gaza  2018     6318.210068
# 7085                World  2018    16679.316815
# 7116               Zambia  2018     3521.545978
# 7147             Zimbabwe  2018     2497.136618

# %% [markdown]
# #### Now, return to the full dataset, `gdp_df`. Pivot the data for 1990 and 2018 (using the pandas `.pivot_table()` method or another method) so that each row corresponds to a country, each column corresponds to a year, and the values in the table give the GDP_Per_Capita amount.  Drop any rows that are missing values for either 1990 or 2018. Save the result to a dataframe named `gdp_pivoted`.

# %%
#Original DF

gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
# Dataframe displaying years 1990 AND 2018

gdp_df_2_yrs = gdp_df.loc[(gdp_df['Year'] == 1990) | (gdp_df['Year'] == 2018)] 
gdp_df_2_yrs
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 49    Africa Eastern and Southern  1990     3083.976800
# 52     Africa Western and Central  2018     4132.592996
# 80     Africa Western and Central  1990     2810.341129
# ...                           ...   ...             ...
# 7113                        World  1990     9704.621768
# 7116                       Zambia  2018     3521.545978
# 7144                       Zambia  1990     2190.181724
# 7147                     Zimbabwe  2018     2497.136618
# 7175                     Zimbabwe  1990     2652.129209
#
# [448 rows x 3 columns]

# %%
## Dataframe.pivot for years 1990 AND 2018

pivot_2_yrs = gdp_df_2_yrs.pivot_table(index = 'Country', columns = 'Year', values = 'GDP_Per_Capita').dropna()
pivot_2_yrs
# Out:
# Year                                1990          2018
# Country
# Africa Eastern and Southern  3083.976800   3697.317275
# Africa Western and Central   2810.341129   4132.592996
# Albania                      4827.034551  13317.092313
# Algeria                      8746.340762  11630.679409
# Angola                       5758.950488   6982.129420
# ...                                  ...           ...
# Vanuatu                      2855.554643   3093.086718
# Vietnam                      2066.372215   9548.700016
# World                        9704.621768  16679.316815
# Zambia                       2190.181724   3521.545978
# Zimbabwe                     2652.129209   2497.136618
#
# [206 rows x 2 columns]

# %%
#gdp_df_yrs_pivoted = gdp_df_yrs.pivot_table(gdp_df_yrs, index = 'Year')
#gdp_df_yrs_pivoted

# %%
#gdp_df_yrs_pivoted = gdp_df_yrs.pivot_table(index = 'Country', columns= 'Year', values='GDP_Per_Capita').dropna()
#gdp_df_yrs_pivoted

# %% [markdown]
# #### Create a new column in `gdp_pivoted` named `Percent_Change`.  Column should contain the percent change in GDP_Per_Capita from 1990 to 2018.
# ** Hint: Percent change is calculated as 100*(New Value - Old Value) / Old Value.

# %%
#Dataframe Percent Change for years 1990 AND 2018

#df[percent] = (df['column_name'] / df['column_name'].sum()) * 100

pivot_2_yrs['Percent_Change'] = (pivot_2_yrs[1990] / 
                                 pivot_2_yrs[2018].sum()) * 100 
pivot_2_yrs
# Out:
# Year                                1990          2018  Percent_Change
# Country
# Africa Eastern and Southern  3083.976800   3697.317275        0.075524
# Africa Western and Central   2810.341129   4132.592996        0.068823
# Albania                      4827.034551  13317.092313        0.118209
# Algeria                      8746.340762  11630.679409        0.214189
# Angola                       5758.950488   6982.129420        0.141031
# ...                                  ...           ...             ...
# Vanuatu                      2855.554643   3093.086718        0.069930
# Vietnam                      2066.372215   9548.700016        0.050603
# World                        9704.621768  16679.316815        0.237657
# Zambia                       2190.181724   3521.545978        0.053635
# Zimbabwe                     2652.129209   2497.136618        0.064948
#
# [206 rows x 3 columns]

# %% [markdown]
# #### How many countries experienced a negative percent change in GDP per capita from 1990 to 2018?

# %%
#gdp_df_yrs_pivoted['Percent_Change'].value_counts()

pivot_2_yrs.sort_values(by= 'Percent_Change', ascending=True)
# Out:
# Year                           1990           2018  Percent_Change
# Country
# Mozambique               471.325103    1289.735948        0.011542
# Myanmar                  564.227113    4467.858550        0.013817
# Ethiopia                 767.013565    2103.515858        0.018783
# Uganda                   913.726756    2124.792203        0.022376
# Rwanda                   936.634310    2088.749474        0.022937
# ...                             ...            ...             ...
# Switzerland            56329.215654   70597.292069        1.379448
# Bermuda                65961.406278   81423.408453        1.615331
# Luxembourg             70860.819124  115049.926079        1.735313
# Brunei                 71232.789430   60389.184647        1.744422
# United Arab Emirates  111454.055665   66968.221181        2.729402
#
# [206 rows x 3 columns]

# %% [markdown]
# #### Now, return to the full dataset, `gdp_df`.

# %%
#DATAFRAME W ALL YEARS

gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# #### Pivot the data for 1990 and 2018 [1990 - 2018].
#    Row = country, Column = year, and values = GDP_Per_Capita.
#    - Drop any rows that are missing values for either 1990 or 2018.
#    - Save to a dataframe named gdp_pivoted.

# %%
gdp_pivoted = gdp_df.pivot_table(index = 'Country', columns = 'Year', values = 'GDP_Per_Capita').dropna()
gdp_pivoted
# Out:
# Year                                1990         1991         1992  \
# Country
# Africa Eastern and Southern  3083.976800  2998.435307  2858.935715
# Africa Western and Central   2810.341129  2770.672791  2764.956399
# Albania                      4827.034551  3496.374584  3264.825387
# Algeria                      8746.340762  8431.377821  8383.758348
# Angola                       5758.950488  5625.868744  5126.464246
# Angola                        7569.209398   7310.896551   6982.129420
# ...                                   ...           ...           ...
# Vanuatu                       2973.107324   3081.461777   3093.086718
# Vietnam                       8498.811285   8996.378103   9548.700016
# World                        15868.937024  16276.481191  16679.316815
# Zambia                        3467.887448   3485.021780   3521.545978
# Zimbabwe                      2341.304920   2416.049969   2497.136618
#
# Year                                 2019          2020
# Country
# Africa Eastern and Southern   3684.315172   3491.978104
# Africa Western and Central    4159.844650   4021.293919
# Albania                      13653.201570  13253.733337
# Algeria                      11521.984210  10735.382539
# Angola                        6712.021615   6141.963839
# ...                                   ...           ...
# Vanuatu                       3116.594618   2878.475335
# Vietnam                      10134.259028  10338.270543
# World                        16973.695660  16269.969854
# Zambia                        3470.435511   3277.816510
# Zimbabwe                      2310.634802   2134.555461
#
# [205 rows x 31 columns]

# %% [markdown]
# #### Create a new column in `gdp_pivoted` named `Percent_Change`.  Column should contain the percent change in GDP_Per_Capita from 1990 to 2018.
# *** Hint: Percent change is calculated as 100*(New Value - Old Value) / Old Value.

# %%
#df[percent] = (df['column_name'] / df['column_name'].sum()) * 100

gdp_pivoted['Percent_Change'] = (gdp_pivoted[1990] / 
                                 gdp_pivoted[2018].sum()) * 100 
gdp_pivoted
# Out:
# Year                                1990         1991         1992  \
# Country
# Africa Eastern and Southern  3083.976800  2998.435307  2858.935715
# Africa Western and Central   2810.341129  2770.672791  2764.956399
# Albania                      4827.034551  3496.374584  3264.825387
# Algeria                      8746.340762  8431.377821  8383.758348
# Angola                       5758.950488  5625.868744  5126.464246
# ...                                  ...          ...          ...
# Vanuatu                      2855.554643  2864.471760  2854.110143
# Vietnam                      2066.372215  2143.882680  2281.710499
# World                        9704.621768  9676.445982  9679.179969
# Zambia                       2190.181724  2133.687490  2045.973499
# Zimbabwe                     2652.129209  2733.696626  2437.152908
#
# Year                                1993         1994         1995  \
# Country
# Africa Eastern and Southern  2768.082812  2741.742703  2788.868510
# Africa Western and Central   2664.878345  2593.404383  2579.822162
# Albania                      3598.815371  3921.620532  4471.608044
# Algeria                      8027.365901  7792.074446  7935.168924
# Angola                       3772.474231  3701.631031  4122.119240
# ...                                  ...          ...          ...
# Vanuatu                      2792.902454  2965.144707  2923.086222
# Vietnam                      2417.584142  2583.011070  2781.879905
# World                        9685.460401  9808.678214  9966.545199
# Zambia                       2133.263601  1902.392868  1908.698795
# Zimbabwe                     2420.092791  2603.927369  2573.993785
#
# Year                                 1996          1997          1998  \
# Country
# Africa Eastern and Southern   2864.243325   2910.470139   2888.955036
# Africa Western and Central    2630.296470   2672.029674   2694.491443
# Albania                       4908.939354   4400.318994   4819.074667
# Algeria                       8116.949627   8074.749415   8360.140817
# Angola                        4532.384971   4708.144428   4772.398548
# ...                                   ...           ...           ...
# Vanuatu                       2929.106508   3016.686951   2999.543432
# Vietnam                       2995.392754   3194.872036   3336.539165
# World                        10197.630253  10445.982557  10555.092444
# Zambia                        1974.615070   1994.849295   1933.003767
# Zimbabwe                      2808.558556   2856.118188   2915.052992
# Africa Eastern and Southern   3677.319414   3694.915103   3691.284532
# Africa Western and Central    4215.646000   4216.409204   4121.249120
# Albania                      11586.833878  11878.454448  12291.859492
# Algeria                      11512.690472  11696.950357  11826.151380
# Angola                        8240.347981   8036.631076   7569.209398
# ...                                   ...           ...           ...
# Vanuatu                       2984.243485   2915.347170   2973.107324
# Vietnam                       7601.858491   8048.696327   8498.811285
# World                        15224.439424  15549.085622  15868.937024
# Zambia                        3450.037600   3443.553254   3467.887448
# Zimbabwe                      2357.651166   2360.022385   2341.304920
#
# Year                                 2017          2018          2019  \
# Country
# Africa Eastern and Southern   3694.912741   3697.317275   3684.315172
# Africa Western and Central    4115.645480   4132.592996   4159.844650
# Albania                      12770.964291  13317.092313  13653.201570
# Algeria                      11737.401235  11630.679409  11521.984210
# Angola                        7310.896551   6982.129420   6712.021615
# ...                                   ...           ...           ...
# Vanuatu                       3081.461777   3093.086718   3116.594618
# Vietnam                       8996.378103   9548.700016  10134.259028
# World                        16276.481191  16679.316815  16973.695660
# Zambia                        3485.021780   3521.545978   3470.435511
# Zimbabwe                      2416.049969   2497.136618   2310.634802
#
# Year                                 2020  Percent_Change
# Country
# Africa Eastern and Southern   3491.978104        0.075799
# Africa Western and Central    4021.293919        0.069074
# Albania                      13253.733337        0.118641
# Algeria                      10735.382539        0.214971
# Angola                        6141.963839        0.141546
# ...                                   ...             ...
# Vanuatu                       2878.475335        0.070185
# Vietnam                      10338.270543        0.050788
# World                        16269.969854        0.238524
# Zambia                        3277.816510        0.053831
# Zimbabwe                      2134.555461        0.065185
#
# [197 rows x 32 columns]

# %% [markdown]
# #### Which country had the highest % change in GDP per capita?
# - UAE 2.73% change
#
# #### Create a line plot showing this country's GDP per capita for all years from 1990 to 2018. Create another showing the country with the second highest % change in GDP. How do the trends in these countries compare?
#
# **Bonus:** Put both line charts on the same plot.

# %%
gdp_pivoted_max = gdp_pivoted[gdp_pivoted.Percent_Change == gdp_pivoted.Percent_Change.max()]
gdp_pivoted_max
# Out:
# Year                           1990           1991           1992  \
# Country
# United Arab Emirates  111454.055665  106103.552655  103470.924576
#
# Year                          1993           1994         1995           1996  \
# Country
# United Arab Emirates  98978.474614  100213.156226  101570.9921  102211.638844
#
# Year                           1997           1998          1999  ...  \
# Country                                                           ...
# United Arab Emirates  105108.996265  100100.435658  97698.537395  ...
#
# Year                          2012          2013          2014          2015  \
# Country
# United Arab Emirates  57389.318786  59920.152313  62452.184508  65267.415127
#
# Year                          2016          2017          2018          2019  \
# Country
# United Arab Emirates  66510.893666  67183.605312  66968.221181  68263.675535
#
# Year                          2020  Percent_Change
# Country
# United Arab Emirates  63299.422971        2.739361
#
# [1 rows x 32 columns]

# %%
gdp_pivoted_min = gdp_pivoted[gdp_pivoted.Percent_Change == gdp_pivoted.Percent_Change.min()]
gdp_pivoted_min
# Out:
# Year              1990        1991        1992        1993        1994  \
# Country
# Mozambique  471.325103  481.896856  436.720371  464.018358  475.249723
#
# Year              1995       1996        1997        1998        1999  ...  \
# Country                                                                ...
# Mozambique  469.189504  506.15182  548.347795  587.863721  640.252516  ...
#
# Year               2012         2013         2014         2015         2016  \
# Country
# Mozambique  1120.128481  1165.408205  1217.088867  1262.613128  1273.783633
#
# Year              2017         2018         2019         2020  Percent_Change
# Country
# Mozambique  1283.65987  1289.735948  1281.780014  1229.940296        0.011584
#
# [1 rows x 32 columns]

# %%
gdp_pivoted['Percent_Change'].max()
gdp_pivoted_max
# Out:
# Year                           1990           1991           1992  \
# Country
# United Arab Emirates  111454.055665  106103.552655  103470.924576
#
# Year                          1993           1994         1995           1996  \
# Country
# United Arab Emirates  98978.474614  100213.156226  101570.9921  102211.638844
#
# Year                           1997           1998          1999  ...  \
# Country                                                           ...
# United Arab Emirates  105108.996265  100100.435658  97698.537395  ...
#
# Year                          2012          2013          2014          2015  \
# Country
# United Arab Emirates  57389.318786  59920.152313  62452.184508  65267.415127
#
# Year                          2016          2017          2018          2019  \
# Country
# United Arab Emirates  66510.893666  67183.605312  66968.221181  68263.675535
#
# Year                          2020  Percent_Change
# Country
# United Arab Emirates  63299.422971        2.739361
#
# [1 rows x 32 columns]

# %%
gdp_pivoted_min = gdp_pivoted['Percent_Change'].min()
gdp_pivoted_min
# Out:
# 0.011584412643072995

# %%
gdp_pivoted.plot.line()
plt.show()

# %%
#gdp_pivoted = gdp_pivoted.set_index('Percent_Change')
#gdp_pivoted

#gdp_pivoted.plot.line()
#plt.show()

#gdp_pivoted = gdp_pivoted.groupby['Percent_Change'].agg({'Highest_Percen_Change' : max, 'Lowest_Percent_Change' : min})

# %%
# Get the min & max temperatures
#df = seattle_temps.groupby('date').agg(['min','max'])
#print(df)

gdp_pivoted_m =  gdp_pivoted.groupby('Percent_Change').agg([min, max])
gdp_pivoted_m
# Out:
# Year                     1990                          1991                 \
#                           min            max            min            max
# Percent_Change
# 0.011584           471.325103     471.325103     481.896856     481.896856
# 0.013868           564.227113     564.227113     562.648089     562.648089
# 0.018852           767.013565     767.013565     687.543151     687.543151
# 0.022458           913.726756     913.726756     932.289859     932.289859
# 0.023021           936.634310     936.634310     939.501467     939.501467
# ...                       ...            ...            ...            ...
# 1.384481         56329.215654   56329.215654   55120.114761   55120.114761
# 1.621225         65961.406278   65961.406278   63958.896254   63958.896254
# 1.741645         70860.819124   70860.819124   75961.668717   75961.668717
# 1.750787         71232.789430   71232.789430   71405.378117   71405.378117
# 2.739361        111454.055665  111454.055665  106103.552655  106103.552655
#
# Year                     1992                         1993                \
#                           min            max           min           max
# Percent_Change
# 0.011584           436.720371     436.720371    464.018358    464.018358
# 0.013868           580.809734     580.809734    618.793560    618.793560
# 0.018852           605.770668     605.770668    661.312446    661.312446
# 0.022458           932.570218     932.570218    977.855579    977.855579
# 0.023021          1051.322073    1051.322073   1033.701525   1033.701525
# ...                       ...            ...           ...           ...
# 1.384481         54491.900350   54491.900350  53929.858518  53929.858518
# 1.621225         64385.407410   64385.407410  65967.850014  65967.850014
# 1.741645         76323.304753   76323.304753  78468.921760  78468.921760
# 1.750787         72705.728039   72705.728039  70908.808194  70908.808194
# 2.739361        103470.924576  103470.924576  98978.474614  98978.474614
#
# Year                     1994                 ...           2016  \
#                           min            max  ...            min
# Percent_Change                                ...
# 0.011584           475.249723     475.249723  ...    1273.783633
# 0.013868           653.231210     653.231210  ...    4020.242953
# 0.018852           659.091401     659.091401  ...    1894.897364
# 0.022458          1008.011286    1008.011286  ...    2088.647514
# 0.023021           542.659841     542.659841  ...    1950.526265
# ...                       ...            ...  ...            ...
# 1.384481         54181.002566   54181.002566  ...   68663.243823
# 1.621225         65904.720421   65904.720421  ...   78149.352535
# 1.741645         80365.224508   80365.224508  ...  116283.699681
# 1.750787         71176.341934   71176.341934  ...   60867.291866
# 2.739361        100213.156226  100213.156226  ...   66510.893666
#
# Year                                    2017                          2018  \
#                           max            min            max            min
# Percent_Change
# 0.011584          1273.783633    1283.659870    1283.659870    1289.735948
# 0.013868          4020.242953    4224.545031    4224.545031    4467.858550
# 0.018852          1894.897364    2021.562908    2021.562908    2103.515858
# 0.022458          2088.647514    2074.652436    2074.652436    2124.792203
# 0.023021          1950.526265    1975.248661    1975.248661    2088.749474
# ...                       ...            ...            ...            ...
# 1.384481         68663.243823   69103.570265   69103.570265   70597.292069
# 1.621225         78149.352535   81834.955874   81834.955874   81423.408453
# 1.741645        116283.699681  114985.842236  114985.842236  115049.926079
# 1.750787         60867.291866   60994.531556   60994.531556   60389.184647
# 2.739361         66510.893666   67183.605312   67183.605312   66968.221181
#
# Year                                    2019                          2020  \
#                           max            min            max            min
# Percent_Change
# 0.011584          1289.735948    1281.780014    1281.780014    1229.940296
# 0.013868          4467.858550    4739.710438    4739.710438    4857.389834
# 0.018852          2103.515858    2221.404665    2221.404665    2296.890440
# 0.022458          2124.792203    2182.899761    2182.899761    2175.031098
# 0.023021          2088.749474    2227.515571    2227.515571    2098.635559
# ...                       ...            ...            ...            ...
# 1.384481         70597.292069   70944.354813   70944.354813   68755.437033
# 1.621225         81423.408453   81681.726668   81681.726668   76105.138057
# 1.741645        115049.926079  116518.276815  116518.276815  112557.309472
# 1.750787         60389.184647   62098.011380   62098.011380   62200.882043
# 2.739361         66968.221181   68263.675535   68263.675535   63299.422971
#
# Year
#                           max
# Percent_Change
# 0.011584          1229.940296
# 0.013868          4857.389834
# 0.018852          2296.890440
# 0.022458          2175.031098
# 0.023021          2098.635559
# ...                       ...
# 1.384481         68755.437033
# 1.621225         76105.138057
# 1.741645        112557.309472
# 1.750787         62200.882043
# 2.739361         63299.422971
#
# [204 rows x 62 columns]

# %%
gdp_pivoted_m =  gdp_pivoted.groupby('Country').agg([min, max])
gdp_pivoted_m
# Out:
# Year                                1990                      1991  \
#                                      min          max          min
# Country
# Africa Eastern and Southern  3083.976800  3083.976800  2998.435307
# Africa Western and Central   2810.341129  2810.341129  2770.672791
# Albania                      4827.034551  4827.034551  3496.374584
# Algeria                      8746.340762  8746.340762  8431.377821
# Angola                       5758.950488  5758.950488  5625.868744
# Algeria                      11521.984210  10735.382539  10735.382539
# Angola                        6712.021615   6141.963839   6141.963839
# ...                                   ...           ...           ...
# Vanuatu                       3116.594618   2878.475335   2878.475335
# Vietnam                      10134.259028  10338.270543  10338.270543
# World                        16973.695660  16269.969854  16269.969854
# Zambia                        3470.435511   3277.816510   3277.816510
# Zimbabwe                      2310.634802   2134.555461   2134.555461
#
# Year                        Percent_Change
#                                        min       max
# Country
# Africa Eastern and Southern       0.075799  0.075799
# Africa Western and Central        0.069074  0.069074
# Albania                           0.118641  0.118641
# Algeria                           0.214971  0.214971
# Angola                            0.141546  0.141546
# ...                                    ...       ...
# Vanuatu                           0.070185  0.070185
# Vietnam                           0.050788  0.050788
# World                             0.238524  0.238524
# Zambia                            0.053831  0.053831
# Zimbabwe                          0.065185  0.065185
#
# [205 rows x 64 columns]

# %%
gdp_pivoted.plot.line()
plt.show()

# %%
gdp_pivoted['Percent_Change', index = ].plot()
gdp_pivoted.plot()
# Out:
#   Input In [41]
#     gdp_pivoted['Percent_Change', index = ].plot()
#                                         ^
# SyntaxError: invalid syntax

# %%
gdp_pivoted.head(5)

# %%
gdp_pivoted_m.head(2)

# %%
gdp_pivoted_m['Percent_Change'].plot()
gdp_pivoted_m.plot()

# %%
gdp_pivoted_m.plot()

# %%
Percent_Change

# %%
gdp_pivoted_m.plot(rot = 60)
plt.xlabel("Year", size = 20)
plt.ylabel("Percentage Change", size = 20)
plt.title("Percentage Change in GDP", size = 25)
plt.show()

# %%
gdp_pivoted_m.plot(subplots = True)
plt.xlabel("Year", size = 20)
plt.ylabel("Percentage Change", size = 20)
plt.title("Percentage Change in GDP", size = 25)
plt.show()

# %%
# Plot the Min/Max Values
gdp_pivoted_m.plot(x= 'Year', y=['Max', 'Min'], figsize=(10,5))

# Set the x-axis label
plt.xlabel(gdp_pivoted_m)

# Set the y-axis label
plt.ylabel('Percent_Change')

# Set the title of the plot
plt.title('GDP Percentage Change')

# Display the plot
plt.show()

# %% [markdown]
# #### Read in continents.csv contained in the `data` folder into a new dataframe called `continents`.

# %%
continents = pd.read_csv('data/continents.csv')
continents

# %% [markdown]
# #### Merge gdp_df and continents. Keep only the countries that appear in both data frames. Save the result back to gdp_df.

# %%
continents = pd.read_csv('')
continents
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 continents = pd.read_csv('continents.csv')
#       2 continents
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'continents.csv'

# %%
gdp_df = pd.read_csv('gdp_per_capita.csv')
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]
