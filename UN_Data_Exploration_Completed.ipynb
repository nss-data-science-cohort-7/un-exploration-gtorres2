# %% [markdown]
# ### Download data set. Create Jupyter Notebook, name it "UN_Data_Exploration". Import Pandas libraries.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %% [markdown]
# ### Read the GDP dataset into your notebook as a DataFrame called `gdp_df'.

# %%
gdp_df = pd.read_csv('gdp_per_capita.csv')
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %% [markdown]
# ### After reading it in, inspect the first 10 rows.

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2020  1970.560169              NaN
# 1     Afghanistan  2019  2065.036235              NaN
# 2     Afghanistan  2018  2033.804389              NaN
# 3     Afghanistan  2017  2058.400221              NaN
# 4     Afghanistan  2016  2057.067978              NaN
# 5     Afghanistan  2015  2068.265904              NaN
# 6     Afghanistan  2014  2102.384604              NaN
# 7     Afghanistan  2013  2116.465258              NaN
# 8     Afghanistan  2012  2075.491614              NaN
# 9     Afghanistan  2011  1904.559926              NaN

# %% [markdown]
# ###  Inspect the last 10 rows.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7166        Zimbabwe  1999  2872.714795              NaN
# 7167        Zimbabwe  1998  2915.052992              NaN
# 7168        Zimbabwe  1997  2856.118188              NaN
# 7169        Zimbabwe  1996  2808.558556              NaN
# 7170        Zimbabwe  1995  2573.993785              NaN
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN

# %% [markdown]
# ### Drop the 'Value Footnotes' column.

# %%
gdp_df = gdp_df.drop(columns=['Value Footnotes'])
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# ### Rename columns to 'Country', 'Year', and 'GDP_Per_Capita'

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area': 'Country', 'Year':'Year', 'Value': 'GDP_Per_Capita'})
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# ### How many rows and columns does gdp_df have?
# 7,176 rows & 3 columns.
# ### What are the data types of its columns?
# Country = object, Year = interger, GDP = float

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7176 entries, 0 to 7175
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7176 non-null   object
#  1   Year            7176 non-null   int64
#  2   GDP_Per_Capita  7176 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 168.3+ KB

# %% [markdown]
# ### Which years are represented in this dataset?
#    From 1990-2018 (28 yrs)
# ### Take a look at the number of observations per year.
#     What do you notice?
#    Growth every year, with steady growth from 2013-2018.

# %%
gdp_df['Year'].value_counts()
# Out:
# 2018    242
# 2017    242
# 2016    242
# 2015    242
# 2014    242
# 2013    242
# 2019    241
# 2020    240
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 1999    227
# 1998    226
# 1997    226
# 1996    222
# 1995    222
# 1994    211
# 1993    209
# 1992    208
# 1991    207
# 1990    206
# Name: Year, dtype: int64

# %% [markdown]
# ### How many countries are represented in this dataset?
#    242 countries
# ### Which countries are least represented in the dataset?
#    Somalia and Djibouti
# ### Why do you think these countries have so few observations?
#    Size

# %%
gdp_df['Country'].value_counts()
# Out:
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: Country, Length: 242, dtype: int64

# %% [markdown]
# ### Create a new dataframe by subsetting `gdp_df` to just the year 2014. Call this new dataframe `gdp_2014`.

# %%
gdp_2014 = gdp_df[gdp_df['Year'] == 2014] 
gdp_2014
# Out:
#                           Country  Year  GDP_Per_Capita
# 6                     Afghanistan  2014     2102.384604
# 25    Africa Eastern and Southern  2014     3677.319414
# 56     Africa Western and Central  2014     4215.646000
# 87                        Albania  2014    11586.833878
# 118                       Algeria  2014    11512.690472
# ...                           ...   ...             ...
# 7031                      Vietnam  2014     7601.858491
# 7062           West Bank and Gaza  2014     5967.073437
# 7089                        World  2014    15224.439424
# 7120                       Zambia  2014     3450.037600
# 7151                     Zimbabwe  2014     2357.651166
#
# [242 rows x 3 columns]

# %% [markdown]
# ### Use `.describe()` to find the summary statistics for GDP per capita in 2014.

# %%
gdp_2014.describe()
# Out:
#          Year  GDP_Per_Capita
# count   242.0      242.000000
# mean   2014.0    19612.875611
# std       0.0    20961.714572
# min    2014.0      822.611195
# 25%    2014.0     4702.212961
# 50%    2014.0    12178.874687
# 75%    2014.0    26461.384188
# max    2014.0   155201.740571

# %% [markdown]
# ### Create a histogram of GDP Per Capita numbers for 2014.
# How would you describe the shape of the distribution?
#      Left skewed.

# %%
gdp_2014.hist(column='GDP_Per_Capita', 
              bins=25, grid=False, figsize=(12,8), color = 'teal', zorder=2, rwidth=0.9)

plt.xlabel('Values')
plt.ylabel('Dollars')
plt.title('Histogram of GDP_Per_Capita')
# Out:
# Text(0.5, 1.0, 'Histogram of GDP_Per_Capita')

# %% [markdown]
# ### Find the top 5 counties and bottom 5 countries by GDP per capita in 2018.

# %%
gdp_2018 = gdp_df[gdp_df['Year'] == 2018] 
gdp_2018
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 52     Africa Western and Central  2018     4132.592996
# 83                        Albania  2018    13317.092313
# 114                       Algeria  2018    11630.679409
# ...                           ...   ...             ...
# 7027                      Vietnam  2018     9548.700016
# 7058           West Bank and Gaza  2018     6318.210068
# 7085                        World  2018    16679.316815
# 7116                       Zambia  2018     3521.545978
# 7147                     Zimbabwe  2018     2497.136618
#
# [242 rows x 3 columns]

# %%
gdp_2018.head(5)
# Out:
#                          Country  Year  GDP_Per_Capita
# 2                    Afghanistan  2018     2033.804389
# 21   Africa Eastern and Southern  2018     3697.317275
# 52    Africa Western and Central  2018     4132.592996
# 83                       Albania  2018    13317.092313
# 114                      Algeria  2018    11630.679409

# %%
gdp_2018.tail(5)
# Out:
#                  Country  Year  GDP_Per_Capita
# 7027             Vietnam  2018     9548.700016
# 7058  West Bank and Gaza  2018     6318.210068
# 7085               World  2018    16679.316815
# 7116              Zambia  2018     3521.545978
# 7147            Zimbabwe  2018     2497.136618

# %% [markdown]
# ### Now, return to the full dataset, `gdp_df`.
# ### Using the`.pivot_table()` method, pivot the data for 1990 and 2018 so that:
#     - Each row corresponds to a country,
#     - Each column corresponds to a year, and
#     - Values in the table give the GDP_Per_Capita amount.
# Drop any rows that are missing values for either 1990 or 2018.
# Save the result to a dataframe named `gdp_pivoted`.

# %%
gdp_df_2_yrs = gdp_df.loc[(gdp_df['Year'] == 1990) | (gdp_df['Year'] == 2018)].dropna() 
gdp_df_2_yrs
# Out:
#                           Country  Year  GDP_Per_Capita
# 2                     Afghanistan  2018     2033.804389
# 21    Africa Eastern and Southern  2018     3697.317275
# 49    Africa Eastern and Southern  1990     3083.976800
# 52     Africa Western and Central  2018     4132.592996
# 80     Africa Western and Central  1990     2810.341129
# ...                           ...   ...             ...
# 7113                        World  1990     9704.621768
# 7116                       Zambia  2018     3521.545978
# 7144                       Zambia  1990     2190.181724
# 7147                     Zimbabwe  2018     2497.136618
# 7175                     Zimbabwe  1990     2652.129209
#
# [448 rows x 3 columns]

# %%
gdp_df_2_yrs = gdp_df_2_yrs.pivot_table(index = 'Country', columns = 'Year', values = 'GDP_Per_Capita').dropna()
gdp_df_2_yrs
# Out:
# Year                                1990          2018
# Country
# Africa Eastern and Southern  3083.976800   3697.317275
# Africa Western and Central   2810.341129   4132.592996
# Albania                      4827.034551  13317.092313
# Algeria                      8746.340762  11630.679409
# Angola                       5758.950488   6982.129420
# ...                                  ...           ...
# Vanuatu                      2855.554643   3093.086718
# Vietnam                      2066.372215   9548.700016
# World                        9704.621768  16679.316815
# Zambia                       2190.181724   3521.545978
# Zimbabwe                     2652.129209   2497.136618
#
# [206 rows x 2 columns]

# %% [markdown]
# ### Create a new column in gdp_pivoted named Percent_Change.
#     Column should contain the percent change in GDP_Per_Capita from 1990 to 2018.
# *** Hint: Percent change is calculated as 100(New Value - Old Value) / Old Value.

# %%
gdp_df_2_yrs['Percent_Change'] = ((gdp_df_2_yrs[2018] - gdp_df_2_yrs[1990]) / 
                                 gdp_df_2_yrs[1990]) * 100  
gdp_df_2_yrs
# Out:
# Year                                1990          2018  Percent_Change
# Country
# Africa Eastern and Southern  3083.976800   3697.317275       19.887973
# Africa Western and Central   2810.341129   4132.592996       47.049515
# Albania                      4827.034551  13317.092313      175.885581
# Algeria                      8746.340762  11630.679409       32.977661
# Angola                       5758.950488   6982.129420       21.239615
# ...                                  ...           ...             ...
# Vanuatu                      2855.554643   3093.086718        8.318247
# Vietnam                      2066.372215   9548.700016      362.099710
# World                        9704.621768  16679.316815       71.869829
# Zambia                       2190.181724   3521.545978       60.787844
# Zimbabwe                     2652.129209   2497.136618       -5.844081
#
# [206 rows x 3 columns]

# %% [markdown]
# ### How many countries experienced a negative percent change in GDP per capita from 1990 to 2018?

# %%
gdp_df_2_yrs.sort_values(by= 'Percent_Change', ascending=True)
# Out:
# Year                                                  1990          2018  \
# Country
# Dem. Rep. Congo                                1819.723315   1085.893688
# United Arab Emirates                         111454.055665  66968.221181
# Burundi                                        1184.842032    761.524143
# Ukraine                                       16428.480469  12336.926758
# Congo                                          5068.286948   3928.427999
# ...                                                    ...           ...
# East Asia & Pacific (IDA & IBRD)               2211.871578  13879.999224
# East Asia & Pacific (excluding high income)    2186.623227  13727.535687
# Myanmar                                         564.227113   4467.858550
# China                                          1423.896348  15133.995618
# Equatorial Guinea                              1039.985049  20386.013868
#
# Year                                         Percent_Change
# Country
# ...

# %% [markdown]
# ### Now, return to the full dataset, `gdp_df`.
# ### Pivot the data for 1990 and 2018 [1990 - 2018].
#    Row = country, Column = year, and values = GDP_Per_Capita.
#    - Drop any rows that are missing values for either 1990 or 2018.
#    - Save to a dataframe named gdp_pivoted.

# %%
gdp_pivoted = gdp_df.pivot_table(index = 'Country', columns = 'Year', values = 'GDP_Per_Capita').dropna()
gdp_pivoted
# Out:
# Year                                1990         1991         1992  \
# Country
# Africa Eastern and Southern  3083.976800  2998.435307  2858.935715
# Africa Western and Central   2810.341129  2770.672791  2764.956399
# Albania                      4827.034551  3496.374584  3264.825387
# Algeria                      8746.340762  8431.377821  8383.758348
# Angola                       5758.950488  5625.868744  5126.464246
# ...                                  ...          ...          ...
# Vanuatu                      2855.554643  2864.471760  2854.110143
# Vietnam                      2066.372215  2143.882680  2281.710499
# World                        9704.621768  9676.445982  9679.179969
# Zambia                       2190.181724  2133.687490  2045.973499
# Zimbabwe                     2652.129209  2733.696626  2437.152908
#
# Year                                1993         1994         1995  \
# Country
# Africa Eastern and Southern  2768.082812  2741.742703  2788.868510
# ...

# %% [markdown]
# ### Create a new column in `gdp_pivoted` named `Percent_Change`.  Column should contain the percent change in GDP_Per_Capita from 1990 to 2018.
# *** Hint: Percent change is calculated as 100*(New Value - Old Value) / Old Value.

# %%
gdp_pivoted['Percent_Change'] = ((gdp_pivoted[2018]- gdp_pivoted[1990]) / 
                                 gdp_pivoted[1990]) * 100 
gdp_pivoted
# Out:
# Year                                1990         1991         1992  \
# Country
# Africa Eastern and Southern  3083.976800  2998.435307  2858.935715
# Africa Western and Central   2810.341129  2770.672791  2764.956399
# Albania                      4827.034551  3496.374584  3264.825387
# Algeria                      8746.340762  8431.377821  8383.758348
# Angola                       5758.950488  5625.868744  5126.464246
# ...                                  ...          ...          ...
# Vanuatu                      2855.554643  2864.471760  2854.110143
# Vietnam                      2066.372215  2143.882680  2281.710499
# World                        9704.621768  9676.445982  9679.179969
# Zambia                       2190.181724  2133.687490  2045.973499
# Zimbabwe                     2652.129209  2733.696626  2437.152908
#
# Year                                1993         1994         1995  \
# Country
# Africa Eastern and Southern  2768.082812  2741.742703  2788.868510
# ...

# %% [markdown]
# ### How many countries experienced a negative percent change in GDP per capita from 1990 to 2018?
# Sixteen in total.
# - Fifteen Countries: Brunei, Burundi, Central African Rep, Congo, Dem Rep. Congo, Gabon, Guinea-Bissau, Haiti, Madagascar, Tajikistan, The Bahamas, The Gambia, Ukraine, UAE, Zimbabwe,
# - "Fragile and Conflict Affected Situations"

# %%
gdp_pivoted[gdp_pivoted['Percent_Change'] <= -1]
# Out:
# Year                                               1990           1991  \
# Country
# Brunei                                     71232.789430   71405.378117
# Burundi                                     1184.842032    1215.887215
# Central African Republic                    1201.674665    1165.240259
# Congo                                       5068.286948    5049.206077
# Dem. Rep. Congo                             1819.723315    1606.326694
# Fragile and conflict affected situations    4874.531032    4345.242878
# Gabon                                      18179.170002   18770.603732
# Guinea-Bissau                               1994.661475    2049.613967
# Haiti                                       3541.410107    3537.293354
# Madagascar                                  1853.049669    1686.157177
# Tajikistan                                  4092.148779    3719.371003
# The Bahamas                                38073.864915   35813.583502
# ...

# %% [markdown]
# ### Which country had the highest % change in GDP per capita?
# - Create a line plot showing this country's GDP per capita for all years from 1990 to 2018.
# -Create another showing the country with the second highest % change in GDP.
# - How do the trends in these countries compare?
# **Bonus:** Put both line charts on the same plot.

# %%
gdp_pivoted.sort_values(by= 'Percent_Change', ascending=False).head(2)
# Out:
# Year                      1990         1991         1992         1993  \
# Country
# Equatorial Guinea  1039.985049   996.878344  1299.925476  1395.403468
# China              1423.896348  1534.705272  1731.657215  1949.534268
#
# Year                      1994         1995         1996         1997  \
# Country
# Equatorial Guinea  1572.062326  1781.264878  2857.502271  6868.493172
# China              2178.924057  2391.477116  2601.363426  2812.711135
#
# Year                      1998         1999  ...          2012          2013  \
# Country                                      ...
# Equatorial Guinea  8165.994032  9851.275584  ...  36671.357436  33678.737836
# China              3004.427342  3206.730026  ...  10370.726572  11101.938930
#
# Year                       2014          2015          2016          2017  \
# Country
# Equatorial Guinea  32436.553501  28313.433159  24827.032116  22550.958161
# China              11851.404218  12612.351651  13399.137320  14243.532611
#
# ...

# %%
gdp_pivoted_df = gdp_pivoted.sort_values(by= 'Percent_Change', ascending=False).head(2)
gdp_pivoted_df
# Out:
# Year                      1990         1991         1992         1993  \
# Country
# Equatorial Guinea  1039.985049   996.878344  1299.925476  1395.403468
# China              1423.896348  1534.705272  1731.657215  1949.534268
#
# Year                      1994         1995         1996         1997  \
# Country
# Equatorial Guinea  1572.062326  1781.264878  2857.502271  6868.493172
# China              2178.924057  2391.477116  2601.363426  2812.711135
#
# Year                      1998         1999  ...          2012          2013  \
# Country                                      ...
# Equatorial Guinea  8165.994032  9851.275584  ...  36671.357436  33678.737836
# China              3004.427342  3206.730026  ...  10370.726572  11101.938930
#
# Year                       2014          2015          2016          2017  \
# Country
# Equatorial Guinea  32436.553501  28313.433159  24827.032116  22550.958161
# China              11851.404218  12612.351651  13399.137320  14243.532611
#
# ...

# %%
gdp_pivot_EG = gdp_pivoted.loc['Equatorial Guinea']
gdp_pivot_EG
# Out:
# Year
# 1990               1039.985049
# 1991                996.878344
# 1992               1299.925476
# 1993               1395.403468
# 1994               1572.062326
# 1995               1781.264878
# 1996               2857.502271
# 1997               6868.493172
# 1998               8165.994032
# 1999               9851.275584
# 2000              11176.518959
# 2001              17523.545157
# 2002              20084.343008
# 2003              21944.505663
# 2004              29004.186721
# 2005              32390.207436
# 2006              33330.890572
# 2007              36685.343353
# 2008              41249.486579
# 2009              39914.175309
# 2010              34732.219150
# 2011              35377.736492
# 2012              36671.357436
# 2013              33678.737836
# 2014              32436.553501
# 2015              28313.433159
# 2016              24827.032116
# 2017              22550.958161
# 2018              20386.013868
# 2019              18600.391775
# ...

# %%
gdp_EG = gdp_pivot_EG.to_frame().reset_index()
gdp_EG
# Out:
#               Year  Equatorial Guinea
# 0             1990        1039.985049
# 1             1991         996.878344
# 2             1992        1299.925476
# 3             1993        1395.403468
# 4             1994        1572.062326
# 5             1995        1781.264878
# 6             1996        2857.502271
# 7             1997        6868.493172
# 8             1998        8165.994032
# 9             1999        9851.275584
# 10            2000       11176.518959
# 11            2001       17523.545157
# 12            2002       20084.343008
# 13            2003       21944.505663
# 14            2004       29004.186721
# 15            2005       32390.207436
# 16            2006       33330.890572
# 17            2007       36685.343353
# 18            2008       41249.486579
# 19            2009       39914.175309
# 20            2010       34732.219150
# 21            2011       35377.736492
# 22            2012       36671.357436
# 23            2013       33678.737836
# ...

# %%
gdp_pivot_EG.plot.line(x= 'Year', y = 'Percent Change')
plt.xlabel('Year')
plt.ylabel('GDP_Per_Capita')
plt.title('Change in Percentage between 1990 & 2018')
plt.show()

# %%
gdp_pivot_CH = gdp_pivoted.loc['China']
gdp_pivot_CH
# Out:
# Year
# 1990               1423.896348
# 1991               1534.705272
# 1992               1731.657215
# 1993               1949.534268
# 1994               2178.924057
# 1995               2391.477116
# 1996               2601.363426
# 1997               2812.711135
# 1998               3004.427342
# 1999               3206.730026
# 2000               3451.679231
# 2001               3712.338132
# 2002               4024.355697
# 2003               4400.825183
# 2004               4817.211845
# 2005               5334.646639
# 2006               5979.781712
# 2007               6795.174012
# 2008               7412.874363
# 2009               8069.354638
# 2010               8884.588031
# 2011               9680.097700
# 2012              10370.726572
# 2013              11101.938930
# 2014              11851.404218
# 2015              12612.351651
# 2016              13399.137320
# 2017              14243.532611
# 2018              15133.995618
# 2019              15977.763828
# ...

# %%
gdp_CH = gdp_pivot_CH.to_frame()
gdp_CH
# Out:
#                        China
# Year
# 1990             1423.896348
# 1991             1534.705272
# 1992             1731.657215
# 1993             1949.534268
# 1994             2178.924057
# 1995             2391.477116
# 1996             2601.363426
# 1997             2812.711135
# 1998             3004.427342
# 1999             3206.730026
# 2000             3451.679231
# 2001             3712.338132
# 2002             4024.355697
# 2003             4400.825183
# 2004             4817.211845
# 2005             5334.646639
# 2006             5979.781712
# 2007             6795.174012
# 2008             7412.874363
# 2009             8069.354638
# 2010             8884.588031
# 2011             9680.097700
# 2012            10370.726572
# 2013            11101.938930
# 2014            11851.404218
# 2015            12612.351651
# 2016            13399.137320
# 2017            14243.532611
# 2018            15133.995618
# 2019            15977.763828
# 2020            16296.778899
# ...

# %%
gdp_pivot_CH.plot.line(x= 'Year', y = 'Percent Change')
plt.xlabel('Year')
plt.ylabel('GDP_Per_Capita')
plt.title('Change in Percentage between 1990 & 2018')
plt.show()

# %%
ax = gdp_pivot_EG.plot.line(x= 'Year', y = 'Percent Change')
gdp_pivot_CH.plot(x= 'Year', y = ['Percent Change'], ax = ax)
plt.xlabel('Year')
plt.ylabel('GDP_Per_Capita')
plt.title('Change in Percentage between 1990 & 2018')
plt.show()

# %% [markdown]
# ### Read in continents.csv contained in the `data` folder into a new dataframe called `continents`.

# %%
continents = pd.read_csv('data/continents.csv')
continents
# Out:
#     Continent             Country
# 0        Asia         Afghanistan
# 1      Europe             Albania
# 2      Africa             Algeria
# 3      Europe             Andorra
# 4      Africa              Angola
# ..        ...                 ...
# 211      Asia             Vietnam
# 212      Asia  West Bank and Gaza
# 213      Asia               Yemen
# 214    Africa              Zambia
# 215    Africa            Zimbabwe
#
# [216 rows x 2 columns]

# %% [markdown]
# ### Merge gdp_df and continents.
# - Keep only the countries that appear in both data frames.
# - Save the result back to gdp_df.

# %%
merged_gdp_df =  pd.merge(gdp_df, continents, on='Country')
merged_gdp_df
# Out:
#           Country  Year  GDP_Per_Capita Continent
# 0     Afghanistan  2020     1970.560169      Asia
# 1     Afghanistan  2019     2065.036235      Asia
# 2     Afghanistan  2018     2033.804389      Asia
# 3     Afghanistan  2017     2058.400221      Asia
# 4     Afghanistan  2016     2057.067978      Asia
# ...           ...   ...             ...       ...
# 5577     Zimbabwe  1994     2603.927369    Africa
# 5578     Zimbabwe  1993     2420.092791    Africa
# 5579     Zimbabwe  1992     2437.152908    Africa
# 5580     Zimbabwe  1991     2733.696626    Africa
# 5581     Zimbabwe  1990     2652.129209    Africa
#
# [5582 rows x 4 columns]

# %% [markdown]
# ### Determine the number of countries per continent.
#     -Create a bar chart showing this.

# %%
merged_gdp_df.value_counts(['Continent'], ascending=False)
# Out:
# Continent
# Africa           1485
# Europe           1316
# Asia             1247
# North America     783
# Oceania           410
# South America     341
# dtype: int64

# %%
merged_gdp_cont = merged_gdp_df['Continent'].value_counts()
merged_gdp_cont.plot(kind='bar')
plt.xlabel('Continent Name')
plt.ylabel('Number of Continents')
plt.title('Countries per Continents')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### Create a seaborn boxplot showing GDP per capita in 2018 split out by continent.
#     - What do you notice?

# %%
merged_gdp_2018 = merged_gdp_df[merged_gdp_df['Year'] == 2018]
merged_gdp_2018
# Out:
#                   Country  Year  GDP_Per_Capita      Continent
# 2             Afghanistan  2018     2033.804389           Asia
# 21                Albania  2018    13317.092313         Europe
# 52                Algeria  2018    11630.679409         Africa
# 83                 Angola  2018     6982.129420         Africa
# 114   Antigua and Barbuda  2018    21017.264500  North America
# ...                   ...   ...             ...            ...
# 5433              Vanuatu  2018     3093.086718        Oceania
# 5464              Vietnam  2018     9548.700016           Asia
# 5495   West Bank and Gaza  2018     6318.210068           Asia
# 5522               Zambia  2018     3521.545978         Africa
# 5553             Zimbabwe  2018     2497.136618         Africa
#
# [188 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (8,6))
sns.boxplot(x = 'Continent', y = 'GDP_Per_Capita', data = merged_gdp_2018)
plt.ylabel('GDP Per Capita')
plt.xticks(rotation = 45)
plt.title('GDP Per Capita by Continent in 2018')
# Out:
# Text(0.5, 1.0, 'GDP Per Capita by Continent in 2018')

# %% [markdown]
# ### Download file 'life expectancy at birth, total (years)'.
# - Read this data life expectancy DataFrame named `life_expectancy`.
#     Note: When reading this dataset it, you may encounter an error.
#     Modify your `read_csv` call to correct this **without modifying the original csv file**.

# %%
life_expectancy = (pd.read_csv('data/life_expectancy.csv', header = 2))
life_expectancy
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code       1960  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.152000
# 1    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.085552
# 2    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.535000
# 3    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.845152
# ...

# %% [markdown]
# ### Drop columns:
#    - Country Code, Indicator Name, and Indicator Code

# %%
life_expectancy = (life_expectancy.drop(columns = ['Country Code', 'Indicator Name', 'Indicator Code']))
life_expectancy
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                          Aruba  64.152000  64.537000  64.752000  65.132000
# 1    Africa Eastern and Southern  44.085552  44.386697  44.752182  44.913159
# 2                    Afghanistan  32.535000  33.068000  33.547000  34.016000
# 3     Africa Western and Central  37.845152  38.164950  38.735102  39.063715
# 4                         Angola  38.211000  37.267000  37.539000  37.824000
# ..                           ...        ...        ...        ...        ...
# 261                       Kosovo  61.485000  61.836000  62.134000  62.440000
# 262                  Yemen, Rep.  33.678000  34.098000  33.615000  33.247000
# 263                 South Africa  52.669000  53.085000  53.376000  53.633000
# 264                       Zambia  49.042000  49.452000  49.794000  50.133000
# 265                     Zimbabwe  53.235000  53.619000  54.071000  54.549000
#
# ...

# %% [markdown]
# ### Use .melt() to convert data from wide to long (multiple rows per country & single column for year).

# %%
life_expectancy = (life_expectancy.melt(id_vars = 'Country Name', var_name = 'Year', value_name = 'life_expectancy')).dropna()
life_expectancy
# Out:
#                       Country Name  Year  life_expectancy
# 0                            Aruba  1960        64.152000
# 1      Africa Eastern and Southern  1960        44.085552
# 2                      Afghanistan  1960        32.535000
# 3       Africa Western and Central  1960        37.845152
# 4                           Angola  1960        38.211000
# ...                            ...   ...              ...
# 16487                       Kosovo  2021        76.806000
# 16488                  Yemen, Rep.  2021        63.753000
# 16489                 South Africa  2021        62.341000
# 16490                       Zambia  2021        61.223000
# 16491                     Zimbabwe  2021        59.253000
#
# [15866 rows x 3 columns]

# %% [markdown]
# ### After melting, rename the columns to `Country`, `Year`, and `Life_Expectancy`

# %%
life_expectancy = life_expectancy.rename(columns = {'Country Name' : 'Country'})
life_expectancy
# Out:
#                            Country  Year  life_expectancy
# 0                            Aruba  1960        64.152000
# 1      Africa Eastern and Southern  1960        44.085552
# 2                      Afghanistan  1960        32.535000
# 3       Africa Western and Central  1960        37.845152
# 4                           Angola  1960        38.211000
# ...                            ...   ...              ...
# 16487                       Kosovo  2021        76.806000
# 16488                  Yemen, Rep.  2021        63.753000
# 16489                 South Africa  2021        62.341000
# 16490                       Zambia  2021        61.223000
# 16491                     Zimbabwe  2021        59.253000
#
# [15866 rows x 3 columns]

# %% [markdown]
# ### What was the first country with a life expectancy to exceed 80?

# %%
life_expectancy[life_expectancy['life_expectancy'] > 80].head(1)
# Out:
#      Country  Year  life_expectancy
# 9695   Japan  1996        80.219756

# %% [markdown]
# ### Merge `gdp_df` and `life_expectancy`, keeping all countries and years that appear in both DataFrames.
# - Save the result to a new DataFrame named `gdp_le`.
#     If you get any errors in doing this, read them carefully and correct them.
# - Look at the first five rows of your new data frame to confirm it merged correctly.
#     Also, check the last five rows to make sure the data is clean and as expected.

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %%
life_expectancy.dtypes
# Out:
# Country             object
# Year                object
# life_expectancy    float64
# dtype: object

# %%
life_expectancy['Year'] = life_expectancy['Year'].astype(int)
life_expectancy
# Out:
#                            Country  Year  life_expectancy
# 0                            Aruba  1960        64.152000
# 1      Africa Eastern and Southern  1960        44.085552
# 2                      Afghanistan  1960        32.535000
# 3       Africa Western and Central  1960        37.845152
# 4                           Angola  1960        38.211000
# ...                            ...   ...              ...
# 16487                       Kosovo  2021        76.806000
# 16488                  Yemen, Rep.  2021        63.753000
# 16489                 South Africa  2021        62.341000
# 16490                       Zambia  2021        61.223000
# 16491                     Zimbabwe  2021        59.253000
#
# [15866 rows x 3 columns]

# %%
life_expectancy.dtypes
# Out:
# Country             object
# Year                 int64
# life_expectancy    float64
# dtype: object

# %%
gdp_le = pd.merge(gdp_df,life_expectancy, on = ['Country', 'Year'], how = 'outer').dropna()
gdp_le
# Out:
#           Country  Year  GDP_Per_Capita  life_expectancy
# 0     Afghanistan  2020     1970.560169           62.575
# 1     Afghanistan  2019     2065.036235           63.565
# 2     Afghanistan  2018     2033.804389           63.081
# 3     Afghanistan  2017     2058.400221           63.016
# 4     Afghanistan  2016     2057.067978           63.136
# ...           ...   ...             ...              ...
# 7171     Zimbabwe  1994     2603.927369           52.588
# 7172     Zimbabwe  1993     2420.092791           54.426
# 7173     Zimbabwe  1992     2437.152908           56.435
# 7174     Zimbabwe  1991     2733.696626           58.091
# 7175     Zimbabwe  1990     2652.129209           59.426
#
# [6520 rows x 4 columns]

# %%
gdp_le.head()
# Out:
#        Country  Year  GDP_Per_Capita  life_expectancy
# 0  Afghanistan  2020     1970.560169           62.575
# 1  Afghanistan  2019     2065.036235           63.565
# 2  Afghanistan  2018     2033.804389           63.081
# 3  Afghanistan  2017     2058.400221           63.016
# 4  Afghanistan  2016     2057.067978           63.136

# %%
gdp_le.tail()
# Out:
#        Country  Year  GDP_Per_Capita  life_expectancy
# 7171  Zimbabwe  1994     2603.927369           52.588
# 7172  Zimbabwe  1993     2420.092791           54.426
# 7173  Zimbabwe  1992     2437.152908           56.435
# 7174  Zimbabwe  1991     2733.696626           58.091
# 7175  Zimbabwe  1990     2652.129209           59.426

# %% [markdown]
# ### Create a new DataFrame, named gdp_le_2019 by extracting data for the year 2019 from gdp_le

# %%
gdp_le_2019 = gdp_le[gdp_le['Year'] == 2019]
gdp_le_2019
# Out:
#                           Country  Year  GDP_Per_Capita  life_expectancy
# 1                     Afghanistan  2019     2065.036235        63.565000
# 20    Africa Eastern and Southern  2019     3684.315172        63.755678
# 51     Africa Western and Central  2019     4159.844650        57.555796
# 82                        Albania  2019    13653.201570        79.282000
# 113                       Algeria  2019    11521.984210        76.474000
# ...                           ...   ...             ...              ...
# 7026                      Vietnam  2019    10134.259028        74.093000
# 7057           West Bank and Gaza  2019     6245.448697        75.241000
# 7084                        World  2019    16973.695660        72.979716
# 7115                       Zambia  2019     3470.435511        62.793000
# 7146                     Zimbabwe  2019     2310.634802        61.292000
#
# [218 rows x 4 columns]

# %% [markdown]
# ### How many countries have a life expectancy of at least 80 in 2019?
# - 179 countries

# %%
gdp_le_2019[gdp_le_2019['life_expectancy'] <= 80].value_counts()
# Out:
# Country                                 Year  GDP_Per_Capita  life_expectancy
# Afghanistan                             2019  2065.036235     63.565000          1
# Samoa                                   2019  6627.838501     72.157000          1
# Nepal                                   2019  3952.760349     69.558000          1
# Nicaragua                               2019  5445.729533     74.054000          1
# Niger                                   2019  1224.375135     62.897000          1
#                                                                                 ..
# Haiti                                   2019  3073.329140     64.255000          1
# Heavily indebted poor countries (HIPC)  2019  2604.617747     63.338057          1
# Honduras                                2019  5736.181633     72.881000          1
# Hungary                                 2019  32553.694473    76.319512          1
# ...

# %% [markdown]
# ### Find the countries that had the top 3 largest GDP per capita figures for 2019.

# %%
gdp_le_2019.sort_values(by= 'GDP_Per_Capita', ascending = False).head(3)
# Out:
#                Country  Year  GDP_Per_Capita  life_expectancy
# 3914  Macao SAR, China  2019   127272.548511        84.978000
# 3883        Luxembourg  2019   116518.276815        82.639024
# 5721         Singapore  2019    98283.308908        83.595122

# %% [markdown]
# ### Create a [seaborn FacetGrid] showing the change in life expectancy over time for these three countries.
# - Each individual figure in the facet grid will represent a single country.

# %%
HK_le = gdp_le[gdp_le['Country'] == 'Hong Kong SAR, China']
HK_le
# Out:
#                    Country  Year  GDP_Per_Capita  life_expectancy
# 2705  Hong Kong SAR, China  2020    55917.647464        85.497561
# 2706  Hong Kong SAR, China  2019    59588.504926        85.180488
# 2707  Hong Kong SAR, China  2018    61055.336624        84.934146
# 2708  Hong Kong SAR, China  2017    59842.212996        84.680488
# 2709  Hong Kong SAR, China  2016    58098.411258        84.226829
# 2710  Hong Kong SAR, China  2015    57214.679808        84.278049
# 2711  Hong Kong SAR, China  2014    56358.055719        83.980488
# 2712  Hong Kong SAR, China  2013    55229.642469        83.831707
# 2713  Hong Kong SAR, China  2012    53783.987564        83.480488
# 2714  Hong Kong SAR, China  2011    53471.854157        83.421951
# 2715  Hong Kong SAR, China  2010    51359.873172        82.978049
# 2716  Hong Kong SAR, China  2009    48458.934135        82.775610
# 2717  Hong Kong SAR, China  2008    49787.765719        82.375610
# ...

# %%
g = sns.FacetGrid(HK_le, col="Country")
g.map(sns.scatterplot, "life_expectancy", "Year")
g.set_titles(col_template="{col_name} Age", fontweight="bold")
g.set_axis_labels("Year of Life_expectancy", "1990-2021")

# %%
Macao_le = gdp_le[gdp_le['Country'] == 'Macao SAR, China']
Macao_le
# Out:
#                Country  Year  GDP_Per_Capita  life_expectancy
# 3913  Macao SAR, China  2020    57728.986403           85.184
# 3914  Macao SAR, China  2019   127272.548511           84.978
# 3915  Macao SAR, China  2018   132373.544079           84.928
# 3916  Macao SAR, China  2017   126144.104058           84.563
# 3917  Macao SAR, China  2016   116519.507535           84.231
# 3918  Macao SAR, China  2015   119406.919122           83.984
# 3919  Macao SAR, China  2014   155201.740571           83.883
# 3920  Macao SAR, China  2013   161971.464661           83.727
# 3921  Macao SAR, China  2012   149702.441471           83.326
# 3922  Macao SAR, China  2011   140321.907954           83.229
# 3923  Macao SAR, China  2010   118085.567175           83.109
# 3924  Macao SAR, China  2009    96493.793065           83.276
# 3925  Macao SAR, China  2008    97345.221572           82.893
# 3926  Macao SAR, China  2007    96154.355383           82.543
# ...

# %%
g = sns.FacetGrid(Macao_le, col="Country")
g = g.map_dataframe(sns.scatterplot, "life_expectancy", "Year")
g.set_titles(col_template="{col_name} Age", fontweight="bold")
g.set_axis_labels("Life_expectancy","Country" )

# %%
JP_le = gdp_le[gdp_le['Country'] == 'Japan']
JP_le
# Out:
#      Country  Year  GDP_Per_Capita  life_expectancy
# 3190   Japan  2020    39935.464722        84.560000
# 3191   Japan  2019    41697.411939        84.356341
# 3192   Japan  2018    41739.203321        84.210976
# 3193   Japan  2017    41444.215744        84.099756
# 3194   Japan  2016    40727.968877        83.984878
# 3195   Japan  2015    40402.581506        83.793902
# 3196   Japan  2014    39739.541124        83.587805
# 3197   Japan  2013    39569.636574        83.331951
# 3198   Japan  2012    38735.896349        83.096098
# 3199   Japan  2011    38149.618108        82.591220
# 3200   Japan  2010    38069.956039        82.842683
# 3201   Japan  2009    36577.863404        82.931463
# 3202   Japan  2008    38781.198727        82.587561
# 3203   Japan  2007    39280.894899        82.507073
# 3204   Japan  2006    38751.005005        82.321951
# 3205   Japan  2005    38250.638011        81.955122
# 3206   Japan  2004    37576.389892        82.030244
# ...

# %%
g = sns.FacetGrid(JP_le, col="Country")
g = g.map_dataframe(sns.scatterplot, "life_expectancy", "Year")
g.set_titles(col_template="{col_name} Age", fontweight="bold")
g.set_axis_labels("Life_expectancy","Country" )

# %%
top_3_le_all_yrs = gdp_le.sort_values(by= 'life_expectancy', ascending = False)
top_3_le_all_yrs
# Out:
#                    Country  Year  GDP_Per_Capita  life_expectancy
# 2705  Hong Kong SAR, China  2020    55917.647464        85.497561
# 3913      Macao SAR, China  2020    57728.986403        85.184000
# 2706  Hong Kong SAR, China  2019    59588.504926        85.180488
# 3914      Macao SAR, China  2019   127272.548511        84.978000
# 2707  Hong Kong SAR, China  2018    61055.336624        84.934146
# ...                    ...   ...             ...              ...
# 5488                Rwanda  1996      816.760626        40.698000
# 5487                Rwanda  1997      870.959678        40.640000
# 5489                Rwanda  1995      746.349712        39.969000
# 941                Burundi  1993     1105.228711        37.105000
# 5490                Rwanda  1994      542.659841        14.098000
#
# [6520 rows x 4 columns]

# %% [markdown]
# ### Create a scatter plot of Life Expectancy vs GDP per Capita for the year 2019.
#     What do you notice?

# %%
gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Per_Capita', y = 'life_expectancy');

# %% [markdown]
# ### Find the correlation between Life Expectancy and GDP per Capita for the year 2019.
# - What is the meaning of this number?
#       A correlation of 0.736 indicates a significant and positive relationship between GDP and life expectancy.

# %%
gdp_le_2019.corr()
# Out:
#                  Year  GDP_Per_Capita  life_expectancy
# Year              NaN             NaN              NaN
# GDP_Per_Capita    NaN        1.000000         0.736861
# life_expectancy   NaN        0.736861         1.000000

# %% [markdown]
# ### Add a column to `gdp_le_2019` and calculate the logarithm of GDP per capita.
#     Find the correlation between the log of GDP per capita and life expectancy.
#     How does this compare to the calculation in the previous part?
#     Look at a scatter plot to see if the result of this calculation makes sense.

# %%
gdp_le_2019['GDP_Log'] = np.log(gdp_le_2019['GDP_Per_Capita'])
gdp_le_2019
# Out:
# /var/folders/zz/36t8l81170j807262t215xf40000gn/T/ipykernel_93611/3570282243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_le_2019['GDP_Log'] = np.log(gdp_le_2019['GDP_Per_Capita'])
#                           Country  Year  GDP_Per_Capita  life_expectancy  \
# 1                     Afghanistan  2019     2065.036235        63.565000
# 20    Africa Eastern and Southern  2019     3684.315172        63.755678
# 51     Africa Western and Central  2019     4159.844650        57.555796
# 82                        Albania  2019    13653.201570        79.282000
# 113                       Algeria  2019    11521.984210        76.474000
# ...                           ...   ...             ...              ...
# ...

# %% [markdown]
# ### Find the correlation between the log of GDP per capita and life expectancy.
# - How does this compare to the calculation in the previous part?
#     Correlation between log of GDP and Life Expectancy is 0.868 meaning there is fairly strong positive relationship

# %%
gdp_le_2019.corr()
# Out:
#                  Year  GDP_Per_Capita  life_expectancy   GDP_Log
# Year              NaN             NaN              NaN       NaN
# GDP_Per_Capita    NaN        1.000000         0.736861  0.853218
# life_expectancy   NaN        0.736861         1.000000  0.868311
# GDP_Log           NaN        0.853218         0.868311  1.000000

# %%
gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Log', y = 'life_expectancy',
                 color = 'teal', alpha = 0.5, label = 'Log of GDP')
# Out:
# <AxesSubplot:xlabel='GDP_Log', ylabel='life_expectancy'>

# %%
gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Per_Capita', y = 'life_expectancy',
            color = 'LightGreen', alpha = 0.5, label = 'GDP')
# Out:
# <AxesSubplot:xlabel='GDP_Per_Capita', ylabel='life_expectancy'>

# %%
#plot.1 -- gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Log', y = 'life_expectancy');
#plot.2 -- gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Per_Capita', y = 'life_expectancy');

#(plot1)
ax = gdp_le_2019.plot(kind = 'scatter', x = 'GDP_Log', y = 'life_expectancy',
                     color = 'teal', alpha = 0.5, label = 'Log of GDP');
#(plot2)
gdp_le_2019.plot(kind = 'scatter', x='GDP_Per_Capita', y= 'life_expectancy',
                 color = 'LightGreen', alpha = 0.5, label = 'GDP', ax=ax);

ax = gdp_le_2019
